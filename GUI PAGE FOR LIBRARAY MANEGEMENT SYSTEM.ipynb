# %%
from tkinter import *
import tkinter.ttk as ttk
from tkinter import messagebox 
import tkinter.simpledialog as sd
import pymysql
import datetime
import tkinter


class LibraryManagementSystem:
    
    def __init__(self,root):
        # Initializing the main GUI window
        self.root=root
        self.root.title('Ragini Library Management System')
        self.root.geometry('1550x1000+0+0')
    #------------------------------Variable--------------------
        self.member_var=StringVar()
        self.prn_var=StringVar()
        self.id_var=StringVar()
        self.firstname_var=StringVar()
        self.lastname_var=StringVar()
        self.address1_var=StringVar()
        self.address2_var=StringVar()
        self.postcode_var=StringVar()
        self.mobile_var=StringVar()
        self.bookid_var=StringVar()
        self.booktitle_var=StringVar()
        self.author_var=StringVar()
        self.dateborrowed_var=StringVar()
        self.datedue_var=StringVar()
        self.daysonbooks_var=StringVar()
        self.lateretufine_var=StringVar()
        self.dateoverdue_var=StringVar()
        self.finallprice_var=StringVar()

        #create title lable
        Label(self.root, bd=10,text='LIBRARY MANAGEMENT SYSTEM', relief=RIDGE,font=("Times New Roman", 50, 'bold'), bg="powder blue", fg='green',padx=2,pady=6).pack(side=TOP, fill=X)

        #create primary frame
        frame = Frame(self.root,bd=12,relief=RIDGE,bg="powder blue",padx=20)
        frame.place(x=0, y=130, height=400, width=1530)

        #create left frame
        left_frame = LabelFrame(frame, bg="powder blue",bd=12,relief=RIDGE,text='LIBRARY Membership Information', font=("Times New Roman", 15, 'bold'),  fg='green')
        left_frame.place(x=0, y=5, width=900, height=350)

        Memberlable=Label(left_frame,text='Member Type',font=("Times New Roman", 12, 'bold'), bg="powder blue", padx=2,pady=6)
        Memberlable.grid(row=0,column=0,sticky=W)

        comMember=ttk.Combobox(left_frame,textvariable=self.member_var,font=("Times New Roman", 12, 'bold'),width=27,state="readonly")
        comMember["value"]=("Admin Staf","Student","Lecturer")
        comMember.current(0)
        comMember.grid(row=0,column=1)

        PRN=Label(left_frame, text='PRN No:',font=("Times New Roman", 12, 'bold'), bg="powder blue", padx=2,pady=6)
        PRN.grid(row=1,column=0,sticky=W)
        txtPrn=Entry(left_frame,textvariable=self.prn_var,font=("Times New Roman", 13, 'bold'), width=29)
        txtPrn.grid(row=1,column=1)

        M_Id=Label(left_frame, text='ID No:',font=("Times New Roman", 12, 'bold'), bg="powder blue", padx=2,pady=6)
        M_Id.grid(row=2,column=0,sticky=W)
        txtId=Entry(left_frame,textvariable=self.id_var,font=("Times New Roman", 13, 'bold'), width=29)
        txtId.grid(row=2,column=1)

        MName=Label(left_frame, text='Firstname',font=("Times New Roman", 12, 'bold'), bg="powder blue", padx=2,pady=6)
        MName.grid(row=3,column=0,sticky=W)
        txtName=Entry(left_frame,textvariable=self.firstname_var,font=("Times New Roman", 13, 'bold'), width=29)
        txtName.grid(row=3,column=1)

        MLast=Label(left_frame, text='Lastname',font=("Times New Roman", 12, 'bold'), bg="powder blue", padx=2,pady=6)
        MLast.grid(row=4,column=0,sticky=W)
        txtLast=Entry(left_frame,textvariable=self.lastname_var,font=("Times New Roman", 13, 'bold'), width=29)
        txtLast.grid(row=4,column=1)

        MAdd1=Label(left_frame, text='Address1',font=("Times New Roman", 12, 'bold'), bg="powder blue", padx=2,pady=6)
        MAdd1.grid(row=5,column=0,sticky=W)
        txtAdd1=Entry(left_frame,textvariable=self.address1_var,font=("Times New Roman", 13, 'bold'), width=29)
        txtAdd1.grid(row=5,column=1)

        MAdd2=Label(left_frame, text='Address2',font=("Times New Roman", 12, 'bold'), bg="powder blue", padx=2,pady=6)
        MAdd2.grid(row=6,column=0,sticky=W)
        txtAdd2=Entry(left_frame,textvariable=self.address2_var,font=("Times New Roman", 13, 'bold'), width=29)
        txtAdd2.grid(row=6,column=1)

        Postcode=Label(left_frame, text='Post Code',font=("Times New Roman", 12, 'bold'), bg="powder blue", padx=2,pady=6)
        Postcode.grid(row=7,column=0,sticky=W)
        txtpc=Entry(left_frame,textvariable=self.postcode_var,font=("Times New Roman", 13, 'bold'), width=29)
        txtpc.grid(row=7,column=1)

        Mobile=Label(left_frame, text='Mobile',font=("Times New Roman", 12, 'bold'), bg="powder blue", padx=2,pady=6)
        Mobile.grid(row=8,column=0,sticky=W)
        txtmn=Entry(left_frame,textvariable=self.mobile_var,font=("Times New Roman", 13, 'bold'), width=29)
        txtmn.grid(row=8,column=1)

        bookid=Label(left_frame, text='Book Id:',font=("Times New Roman", 12, 'bold'), bg="powder blue", padx=2,pady=6)
        bookid.grid(row=0,column=2,sticky=W)
        txtBi=Entry(left_frame,textvariable=self.bookid_var,font=("Times New Roman", 13, 'bold'), width=29)
        txtBi.grid(row=0,column=3)

        BookTitle=Label(left_frame, text='Book Title',font=("Times New Roman", 12, 'bold'), bg="powder blue", padx=2,pady=6)
        BookTitle.grid(row=1,column=2,sticky=W)
        txtBookTitle=Entry(left_frame,
        textvariable=self.booktitle_var,font=("Times New Roman", 13, 'bold'), width=29)
        txtBookTitle.grid(row=1,column=3)

        Author=Label(left_frame, text='Auther Name:',font=("Times New Roman", 12, 'bold'), bg="powder blue", padx=2,pady=6)
        Author.grid(row=2,column=2,sticky=W)
        txtAuthor=Entry(left_frame,textvariable=self.author_var,font=("Times New Roman", 13, 'bold'), width=29)
        txtAuthor.grid(row=2,column=3)

        Dateb=Label(left_frame, text='Date Borrowed',font=("Times New Roman", 12, 'bold'), bg="powder blue", padx=2,pady=6)
        Dateb.grid(row=3,column=2,sticky=W)
        txtDateb=Entry(left_frame,textvariable=self.dateborrowed_var,font=("Times New Roman", 13, 'bold'), width=29)
        txtDateb.grid(row=3,column=3)

        Datedue=Label(left_frame, text='Date Due',font=("Times New Roman", 12, 'bold'), bg="powder blue", padx=2,pady=6)
        Datedue.grid(row=4,column=2,sticky=W)
        txtDatedue=Entry(left_frame,textvariable=self.datedue_var,font=("Times New Roman", 13, 'bold'), width=29)
        txtDatedue.grid(row=4,column=3)

        datsonbook=Label(left_frame, text='Days on Book:',font=("Times New Roman", 12, 'bold'), bg="powder blue", padx=2,pady=6)
        datsonbook.grid(row=5,column=2,sticky=W)
        txtdatsonbook=Entry(left_frame,textvariable=self.daysonbooks_var,font=("Times New Roman", 13, 'bold'), width=29)
        txtdatsonbook.grid(row=5,column=3)

        latereturnFine=Label(left_frame, text='Late Return Fine',font=("Times New Roman", 12, 'bold'), bg="powder blue", padx=2,pady=6)
        latereturnFine.grid(row=6,column=2,sticky=W)
        txtlatereturnFine=Entry(left_frame,textvariable=self.lateretufine_var,font=("Times New Roman", 13, 'bold'), width=29)
        txtlatereturnFine.grid(row=6,column=3)

        Dateover=Label(left_frame, text='Date Over Due',font=("Times New Roman", 12, 'bold'), bg="powder blue", padx=2,pady=6)
        Dateover.grid(row=7,column=2,sticky=W)
        txtDateover=Entry(left_frame,textvariable=self.dateoverdue_var,font=("Times New Roman", 13, 'bold'), width=29)
        txtDateover.grid(row=7,column=3)

        Actualprice=Label(left_frame, text='Actual Price:',font=("Times New Roman", 12, 'bold'), bg="powder blue", padx=2,pady=6)
        Actualprice.grid(row=8,column=2,sticky=W)
        txtActualprice=Entry(left_frame,textvariable=self.finallprice_var,font=("Times New Roman", 13, 'bold'), width=29)
        txtActualprice.grid(row=8,column=3)


        #create Right Frame
        Right_frame = LabelFrame(frame, bg="powder blue",bd=20,relief=RIDGE,text='Book Details', font=("Times New Roman", 15, 'bold'),  fg='green')
        Right_frame.place(x=910, y=5, height=350, width=540)


        self.txtBox=Text(Right_frame,font=("arial", 12, 'bold'),width=32,height=16,padx=2,pady=6)
        self.txtBox.grid(row=0,column=2)
        listScrollbar=Scrollbar(Right_frame)
        listScrollbar.grid(row=0,column=1,sticky="ns")

        listBooks=['Head First Book','Learn Python The Hard Way','Python Programming','Python CookBook','Intro to Machine Learning','Machine tecno','My Python',
                   'Joss Elif Guru','Elise Jungle python','Python for Kids: A Playful Introduction to Programming','Python Basics: A Practical Introduction to Python',
                   'Python Tricks: A Buffet Of Awesome Python Features','Think Python: An Introduction to Software',
                  'Python for Beginners: A Crash Course Guide to Learn Python in 1 Week','Invent Your Own Computer Games with Python',
                   ' Python Basics: A Practical Introduction to Python ','Python Basics: A Practical Introduction to Python']
        def SelectBook(event=""):
            
            value=str(listBox.get(listBox.curselection()))
            x=value
            if(x=="Head First Book"):
                self.bookid_var.set("BKID5451")
                self.booktitle_var.set("Python Manual")
                self.author_var.set("Paul Berry")
                d1=datetime.datetime.today()
                d2=datetime.timedelta(days=15)
                d3=d1+d2
                self.dateborrowed_var.set(d1)
                self.datedue_var.set(d3)
                self.daysonbooks_var.set(15)
                self.lateretufine_var.set("Rs.50")
                self.dateoverdue_var.set("No")
                self.finallprice_var.set("Rs.788")
            elif(x=="Learn Python The Hard Way"):

                self.bookid_var.set("BKID5452")
                self.booktitle_var.set("Python Manual")
                self.author_var.set("Paul Berry")
                d1=datetime.datetime.today()
                d2=datetime.timedelta(days=15)
                d3=d1+d2
                self.dateborrowed_var.set(d1)
                self.datedue_var.set(d3)
                self.daysonbooks_var.set(15)
                self.lateretufine_var.set("Rs.50")
                self.dateoverdue_var.set("No")
                self.finallprice_var.set("768")
            elif(x=="Python Programming"):
                self.bookid_var.set("BKID5453")
                self.booktitle_var.set("Python Manual")
                self.author_var.set("Paul Berry")
                d1=datetime.datetime.today()
                d2=datetime.timedelta(days=15)
                d3=d1+d2
                self.dateborrowed_var.set(d1)
                self.datedue_var.set(d3)
                self.daysonbooks_var.set(15)
                self.lateretufine_var.set("Rs.50")
                self.dateoverdue_var.set("No")
                self.finallprice_var.set("Rs.800")
            elif(x=="Python CookBook"):
                self.bookid_var.set("BKID5454")
                self.booktitle_var.set("Python Manual")
                self.author_var.set("Paul Berry")
                d1=datetime.datetime.today()
                d2=datetime.timedelta(days=15)
                d3=d1+d2
                self.dateborrowed_var.set(d1)
                self.datedue_var.set(d3)
                self.daysonbooks_var.set(15)
                self.lateretufine_var.set("Rs.50")
                self.dateoverdue_var.set("No")
                self.finallprice_var.set("Rs.800")
            elif(x=="Intro to Machine Learning"):
                self.bookid_var.set("BKID5455")
                self.booktitle_var.set("Python Manual")
                self.author_var.set("Paul Berry")
                d1=datetime.datetime.today()
                d2=datetime.timedelta(days=15)
                d3=d1+d2
                self.dateborrowed_var.set(d1)
                self.datedue_var.set(d3)
                self.daysonbooks_var.set(15)
                self.lateretufine_var.set("Rs.50")
                self.dateoverdue_var.set("No")
                self.finallprice_var.set("Rs.800")
            elif(x=="Machine tecno"):
                self.bookid_var.set("BKID5456")
                self.booktitle_var.set("Python Manual")
                self.author_var.set("Paul Berry")
                d1=datetime.datetime.today()
                d2=datetime.timedelta(days=15)
                d3=d1+d2
                self.dateborrowed_var.set(d1)
                self.datedue_var.set(d3)
                self.daysonbooks_var.set(15)
                self.lateretufine_var.set("Rs.50")
                self.dateoverdue_var.set("No")
                self.finallprice_var.set("Rs.800")
            elif(x=="My Python"):
                self.bookid_var.set("BKID5457")
                self.booktitle_var.set("Python Manual")
                self.author_var.set("Paul Berry")
                d1=datetime.datetime.today()
                d2=datetime.timedelta(days=15)
                d3=d1+d2
                self.dateborrowed_var.set(d1)
                self.datedue_var.set(d3)
                self.daysonbooks_var.set(15)
                self.lateretufine_var.set("Rs.50")
                self.dateoverdue_var.set("No")
                self.finallprice_var.set("Rs.800")
            elif(x=="Joss Elif Guru"):
                self.bookid_var.set("BKID5458")
                self.booktitle_var.set("Python Manual")
                self.author_var.set("Paul Berry")
                d1=datetime.datetime.today()
                d2=datetime.timedelta(days=15)
                d3=d1+d2
                self.dateborrowed_var.set(d1)
                self.datedue_var.set(d3)
                self.daysonbooks_var.set(15)
                self.lateretufine_var.set("Rs.50")
                self.dateoverdue_var.set("No")
                self.finallprice_var.set("Rs.800")
            elif(x=="Elise Jungle python"):
                self.bookid_var.set("BKID5459")
                self.booktitle_var.set("Python Manual")
                self.author_var.set("Paul Berry")
                d1=datetime.datetime.today()
                d2=datetime.timedelta(days=15)
                d3=d1+d2
                self.dateborrowed_var.set(d1)
                self.datedue_var.set(d3)
                self.daysonbooks_var.set(15)
                self.lateretufine_var.set("Rs.50")
                self.dateoverdue_var.set("No")
                self.finallprice_var.set("Rs.800")
            elif(x=="Python for Kids: A Playful Introduction to Programming"):
                self.bookid_var.set("BKID5460")
                self.booktitle_var.set("Python Manual")
                self.author_var.set("Paul Berry")
                d1=datetime.datetime.today()
                d2=datetime.timedelta(days=15)
                d3=d1+d2
                self.dateborrowed_var.set(d1)
                self.datedue_var.set(d3)
                self.daysonbooks_var.set(15)
                self.lateretufine_var.set("Rs.50")
                self.dateoverdue_var.set("No")
                self.finallprice_var.set("Rs.800")
            elif(x=="Python Basics: A Practical Introduction to Python"):
                self.bookid_var.set("BKID5461")
                self.booktitle_var.set("Python Manual")
                self.author_var.set("Paul Berry")
                d1=datetime.datetime.today()
                d2=datetime.timedelta(days=15)
                d3=d1+d2
                self.dateborrowed_var.set(d1)
                self.datedue_var.set(d3)
                self.daysonbooks_var.set(15)
                self.lateretufine_var.set("Rs.50")
                self.dateoverdue_var.set("No")
                self.finallprice_var.set("Rs.800")
            elif(x=="Python Tricks: A Buffet Of Awesome Python Features"):
                self.bookid_var.set("BKID5462")
                self.booktitle_var.set("Python Manual")
                self.author_var.set("Paul Berry")
                d1=datetime.datetime.today()
                d2=datetime.timedelta(days=15)
                d3=d1+d2
                self.dateborrowed_var.set(d1)
                self.datedue_var.set(d3)
                self.daysonbooks_var.set(15)
                self.lateretufine_var.set("Rs.50")
                self.dateoverdue_var.set("No")
                self.finallprice_var.set("Rs.800")
            elif(x=="Think Python: An Introduction to Software"):
                self.bookid_var.set("BKID5453")
                self.booktitle_var.set("Python Manual")
                self.author_var.set("Paul Berry")
                d1=datetime.datetime.today()
                d2=datetime.timedelta(days=15)
                d3=d1+d2
                self.dateborrowed_var.set(d1)
                self.datedue_var.set(d3)
                self.daysonbooks_var.set(15)
                self.lateretufine_var.set("Rs.50")
                self.dateoverdue_var.set("No")
                self.finallprice_var.set("Rs.800")
            elif(x=="Python for Beginners: A Crash Course Guide to Learn Python in 1 Week"):
                self.bookid_var.set("BKID5463")
                self.booktitle_var.set("Python Manual")
                self.author_var.set("Paul Berry")
                d1=datetime.datetime.today()
                d2=datetime.timedelta(days=15)
                d3=d1+d2
                self.dateborrowed_var.set(d1)
                self.datedue_var.set(d3)
                self.daysonbooks_var.set(15)
                self.lateretufine_var.set("Rs.50")
                self.dateoverdue_var.set("No")
                self.finallprice_var.set("Rs.800")
            elif(x=="Invent Your Own Computer Games with Python"):
                self.bookid_var.set("BKID5464")
                self.booktitle_var.set("Python Manual")
                self.author_var.set("Paul Berry")
                d1=datetime.datetime.today()
                d2=datetime.timedelta(days=15)
                d3=d1+d2
                self.dateborrowed_var.set(d1)
                self.datedue_var.set(d3)
                self.daysonbooks_var.set(15)
                self.lateretufine_var.set("Rs.50")
                self.dateoverdue_var.set("No")
                self.finallprice_var.set("Rs.800")
            elif(x==" Python Basics: A Practical Introduction to Python"):
                self.bookid_var.set("BKID5465")
                self.booktitle_var.set("Python Manual")
                self.author_var.set("Paul Berry")
                d1=datetime.datetime.today()
                d2=datetime.timedelta(days=15)
                d3=d1+d2
                self.dateborrowed_var.set(d1)
                self.datedue_var.set(d3)
                self.daysonbooks_var.set(15)
                self.lateretufine_var.set("Rs.50")
                self.dateoverdue_var.set("No")
                self.finallprice_var.set("Rs.800")
            elif(x=="Python Basics: A Practical Introduction to Python"):
                self.bookid_var.set("BKID5466")
                self.booktitle_var.set("Python Manual")
                self.author_var.set("Paul Berry")
                d1=datetime.datetime.today()
                d2=datetime.timedelta(days=15)
                d3=d1+d2
                self.dateborrowed_var.set(d1)
                self.datedue_var.set(d3)
                self.daysonbooks_var.set(15)
                self.lateretufine_var.set("Rs.50")
                self.dateoverdue_var.set("No")
                self.finallprice_var.set("Rs.800")
            

        listBox=Listbox(Right_frame ,font=("arial",12,"bold"),width=20,height=16)
        listBox.bind("<<ListboxSelect>>",SelectBook)
        listBox.grid(row=0,column=0,padx=4)
        listScrollbar.config(command=listBox.yview)

        for item in listBooks:
            listBox.insert(END,item)

        #Button Frame
        Bframe = Frame(self.root,bd=12,relief=RIDGE,bg="powder blue",padx=20)
        Bframe.place(x=0, y=530, height=70, width=1530)

        Button(Bframe,text='Add Data', command=self.add_data,font=("arial",12,"bold"), bg="blue",fg="white", width=23 ).grid(row=0,column=0)
        Button(Bframe, text='Show Data',command=self.showData ,font=("arial",12,"bold"),bg="blue",fg="white", width=23 ).grid(row=0,column=1)
        Button(Bframe, text='Update',command=self.update, font=("arial",12,"bold"), bg="blue",fg="white", width=23 ).grid(row=0,column=2)
        Button(Bframe, text='Delete',command=self.delete, font=("arial",12,"bold"), bg="blue",fg="white", width=23 ).grid(row=0,column=3)
        Button(Bframe, text='Reset',command=self.reset, font=("arial",12,"bold"), bg="blue",fg="white", width=23 ).grid(row=0,column=4)
        Button(Bframe, text='Exit', command=self.iExit,font=("arial",12,"bold"), bg="blue",fg="white", width=23 ).grid(row=0,column=5)
        #create Details frame
        frameDetails = Frame(self.root,bd=12,relief=RIDGE,bg="powder blue",padx=20)
        frameDetails.place(x=0, y=600, height=250, width=1530)

        Table_Frame=Frame(frameDetails,bd=6,relief=RIDGE,bg="powder blue")
        Table_Frame.place(x=0, y=2, height=190, width=1460)

        xscroll=ttk.Scrollbar(Table_Frame,orient=HORIZONTAL)
        yscroll=ttk.Scrollbar(Table_Frame,orient=VERTICAL)

        self.libray_table=ttk.Treeview(Table_Frame,column=("Memberlable","PRN","M_Id","MName","MLast","MAdd1","MAdd2","Postcode","Mobile","bookid","BookTitle",
                                                  "Author","Dateb","Datedue","datsonbook","laterreturnFine","Dateover","Actualprice"),xscrollcommand=xscroll.set, yscrollcommand=yscroll.set)

        xscroll.pack(side=BOTTOM, fill=X)
        yscroll.pack(side=RIGHT, fill=Y)

        xscroll.config(command=self.libray_table.xview)
        yscroll.config(command=self.libray_table.yview)

        self.libray_table.heading("Memberlable",text="Member Type")
        self.libray_table.heading("PRN",text="PRN NO")
        self.libray_table.heading("M_Id",text="ID")
        self.libray_table.heading("MName",text="FirstName")
        self.libray_table.heading("MLast",text="LastName")
        self.libray_table.heading("MAdd1",text="Address1")
        self.libray_table.heading("MAdd2",text="Address2")
        self.libray_table.heading("Postcode",text="Postcode")
        self.libray_table.heading("Mobile",text="Mobile")
        self.libray_table.heading("bookid",text="Book Id")
        self.libray_table.heading("BookTitle",text="Book Title")
        self.libray_table.heading("Author",text="Author Name")
        self.libray_table.heading("Dateb",text="Date Borrowed")
        self.libray_table.heading("Datedue",text="Date Due")
        self.libray_table.heading("datsonbook",text="Date on Book")
        self.libray_table.heading("laterreturnFine",text="Late Return Fine")
        self.libray_table.heading("Dateover",text="Date Over")
        self.libray_table.heading("Actualprice",text="Price")
        self.libray_table["show"]="headings"
        self.libray_table.pack(fill=BOTH,expand=1)

        self.libray_table.column("Memberlable",width=100)
        self.libray_table.column("PRN",width=100)
        self.libray_table.column("M_Id",width=100)
        self.libray_table.column("MName",width=100)
        self.libray_table.column("MLast",width=100)
        self.libray_table.column("MAdd1",width=100)
        self.libray_table.column("MAdd2",width=100)
        self.libray_table.column("Postcode",width=100)
        self.libray_table.column("Mobile",width=100)
        self.libray_table.column("bookid",width=100)
        self.libray_table.column("BookTitle",width=100)
        self.libray_table.column("Author",width=100)
        self.libray_table.column("Dateb",width=100)
        self.libray_table.column("Datedue",width=100)
        self.libray_table.column("datsonbook",width=100)
        self.libray_table.column("laterreturnFine",width=100)
        self.libray_table.column("Dateover",width=100)
        self.libray_table.column("Actualprice",width=100)
        self.fatch_data()
        self.libray_table.bind("<ButtonRelease-1>",self.get_cursor)


    def add_data(self):
        try:
        
            connect_db=pymysql.connect(host="localhost",user="root",password="Ragini@23",database="library_manegemnet_system")
            my_cursor=connect_db.cursor()

        
            my_cursor.execute("insert into libraray values(%s,%s,%s,%s,%s,%s,%s,%s,%s,%s,%s,%s,%s,%s,%s,%s,%s,%s)",(
                                                                                                                self.member_var.get(),
                                                                                                                self.prn_var.get(),
                                                                                                                self.id_var.get(),
                                                                                                                self.firstname_var.get(),
                                                                                                                self.lastname_var.get(),
                                                                                                                self.address1_var.get(),
                                                                                                                self.address2_var.get(),
                                                                                                                self.postcode_var.get(),
                                                                                                                self.mobile_var.get(),
                                                                                                                self.bookid_var.get(),
                                                                                                                self.booktitle_var.get(),
                                                                                                                self.author_var.get(),
                                                                                                                self.dateborrowed_var.get(),
                                                                                                                self.datedue_var.get(),
                                                                                                                self.daysonbooks_var.get(),
                                                                                                                self.lateretufine_var.get(),
                                                                                                                self.dateoverdue_var.get(),
                                                                                                                self.finallprice_var.get()
                                                                                                            ))
            connect_db.commit()
            self.fatch_data()
            connect_db.close()
            messagebox.showinfo("Success","Member Has been inserted successfully")
        except Exception as msg:
            print(msg)
    def update(self):
        try:
            connect_db=pymysql.connect(host="localhost",user="root",password="Ragini@23",database="library_manegemnet_system")
            my_cursor=connect_db.cursor()
            my_cursor.execute("update libraray set Member=%s,ID=%s,FirstName=%s,LastName=%s,Address1=%s,Address2=%s,postcode=%s,Mobile=%s,BookId=%s,BookTitle=%s,Author=%s,DateBorrowed=%s,DateDue=%s,DaysonBOOK=%s,LateReturnFine=%s,DateOverDue=%s,Actualprice=%s,PRN_No=%s",(
                                                                                                                    self.member_var.get(),
                                                                                                                    self.id_var.get(),
                                                                                                                    self.firstname_var.get(),
                                                                                                                    self.lastname_var.get(),
                                                                                                                    self.address1_var.get(),
                                                                                                                    self.address2_var.get(),
                                                                                                                    self.postcode_var.get(),
                                                                                                                    self.mobile_var.get(),
                                                                                                                    self.bookid_var.get(),
                                                                                                                    self.booktitle_var.get(),
                                                                                                                    self.author_var.get(),
                                                                                                                    self.dateborrowed_var.get(),
                                                                                                                    self.datedue_var.get(),
                                                                                                                    self.daysonbooks_var.get(),
                                                                                                                    self.lateretufine_var.get(),
                                                                                                                    self.dateoverdue_var.get(),
                                                                                                                    self.finallprice_var.get(),
                                                                                                                    self.prn_var.get()
                                                                                                                ))
            connect_db.commit()
            self.fatch_data()
            self.reset()
            connect_db.close()
            messagebox.showinfo("Success","Member Has been Updated successfully")
        except Exception as msg:
            print(msg)
    def fatch_data(self):
        connect_db=pymysql.connect(host="localhost",user="root",password="Ragini@23",database="library_manegemnet_system")
        my_cursor=connect_db.cursor()
        my_cursor.execute("select* from libraray")
        rows=my_cursor.fetchall()
        if len(rows)!=0:
            self.libray_table.delete(*self.libray_table.get_children())
            for i in rows:
                self.libray_table.insert("",END,values=i)
                connect_db.commit()
        connect_db.close()
    def get_cursor(self,event=""):
        cursor_row=self.libray_table.focus()
        content=self.libray_table.item(cursor_row)
        row=content['values']
        
        self.member_var.set(row[0]),
        self.prn_var.set(row[1]),
        self.id_var.set(row[2]),
        self.firstname_var.set(row[3]),
        self.lastname_var.set(row[4]),
        self.address1_var.set(row[5]),
        self.address2_var.set(row[6]),
        self.postcode_var.set(row[7]),
        self.mobile_var.set(row[8]),
        self.bookid_var.set(row[9]),
        self.booktitle_var.set(row[10]),
        self.author_var.set(row[11]),
        self.dateborrowed_var.set(row[12]),
        self.datedue_var.set(row[13]),
        self.daysonbooks_var.set(row[14]),
        self.lateretufine_var.set(row[15]),
        self.dateoverdue_var.set(row[16]),
        self.finallprice_var.set(row[17])
    def showData(self):
        self.txtBox.insert(END,"Member Type\t\t"+self.member_var.get()+"\n")
        self.txtBox.insert(END,"PRN NO\t\t"+self.prn_var.get()+"\n")
        self.txtBox.insert(END,"ID NO\t\t"+self.id_var.get()+"\n")
        self.txtBox.insert(END,"First Name\t\t"+self.firstname_var.get()+"\n")
        self.txtBox.insert(END,"Last Name\t\t"+self.lastname_var.get()+"\n")
        self.txtBox.insert(END,"Address1\t\t"+self.address1_var.get()+"\n")
        self.txtBox.insert(END,"Address2\t\t"+self.address2_var.get()+"\n")
        self.txtBox.insert(END,"Post Code\t\t"+self.postcode_var.get()+"\n")
        self.txtBox.insert(END,"Mobile No\t\t"+self.mobile_var.get()+"\n")
        self.txtBox.insert(END,"Book ID\t\t"+self.bookid_var.get()+"\n")
        self.txtBox.insert(END,"Book Title\t\t"+self.booktitle_var.get()+"\n")
        self.txtBox.insert(END,"Auther\t\t"+self.author_var.get()+"\n")
        self.txtBox.insert(END,"DateBorrowed\t\t"+self.dateborrowed_var.get()+"\n")
        self.txtBox.insert(END,"Dtae Due\t\t"+self.datedue_var.get()+"\n")
        self.txtBox.insert(END,"DaysOnBook\t\t"+self.daysonbooks_var.get()+"\n")
        self.txtBox.insert(END,"LateRateFine\t\t"+self.lateretufine_var.get()+"\n")
        self.txtBox.insert(END,"DateOverDue\t\t"+self.dateoverdue_var.get()+"\n")
        self.txtBox.insert(END,"FinalPrice:\t\t"+self.finallprice_var.get()+"\n")
    def reset(self):
        self.member_var.set(""),
        self.prn_var.set(""),
        self.id_var.set(""),
        self.firstname_var.set(""),
        self.lastname_var.set(""),
        self.address1_var.set(""),
        self.address2_var.set(""),
        self.postcode_var.set(""),
        self.mobile_var.set(""),
        self.bookid_var.set(""),
        self.booktitle_var.set(""),
        self.author_var.set(""),
        self.dateborrowed_var.set(""),
        self.datedue_var.set(""),
        self.daysonbooks_var.set(""),
        self.lateretufine_var.set(""),
        self.dateoverdue_var.set(""),
        self.finallprice_var.set("")
        self.txtBox.delete("1.0",END)
    def iExit(self):
        iExit=tkinter.messagebox.askyesno("Library Management System","Doyou want to exit")
        if iExit>0:
            self.root.destroy()
            return
    def delete(self):
        if self.prn_var.get()=="" or self.id_var.get()=="":
            messagebox.showerror("Error","First Select the Member")
        else:
            
            connect_db=pymysql.connect(host="localhost",user="root",password="Ragini@23",database="library_manegemnet_system")
            my_cursor=connect_db.cursor()
            query="delete from libraray where PRN_No=%s"
            value=(self.prn_var.get(),)
            my_cursor.execute(query,value)
            connect_db.commit()
            connect_db.commit()
            self.fatch_data()
            self.reset()
            connect_db.close()
            messagebox.showinfo("Success","Member Has been Deleted successfully")
            
        
    


if __name__=="__main__":
    root=Tk()
    obj=LibraryManagementSystem(root)
    

    root.mainloop()
